# %% [markdown]
# DataSet 1

# %%
import scipy.io as scipy
import math

mat = scipy.loadmat('grupoDados1.mat')
grupoTeste = mat['grupoTest']
grupoTreino = mat['grupoTrain']
testeRots = mat['testRots']
treinoRots = mat['trainRots']

# %%
# def normalizacao(dados):
#     min_dados = min(dados)
#     max_dados = max(dados)
#     lista = []
#     for i in dados:
#         lista.append((i - min_dados) / (max_dados - min_dados))
#     return lista

# def padronizacao(x):
#     z = (x - x.mean()) / x.std()
#     return z

def dist(x, y):
    soma = 0
    for i in range(len(x)):
        soma += (x[i] - y[i])**2
    return math.sqrt(soma)

def meuKnn(dadosTreino, rotuloTreino, dadosTeste, k):
    distancias = []
    for i in range(len(dadosTeste)):
        for j in range(len(dadosTreino)):
            distancia = dist(dadosTeste[i], dadosTreino[j])
            distancias.append((distancia, int(rotuloTreino[j][0])))
        distanciasOrdenadas = sorted(distancias)
    
    rotulo_previsto = [x[1] for x in distanciasOrdenadas[:k]]
    return max(rotulo_previsto)

# rotuloPrevisto = meuKnn(grupoTreino, treinoRots, grupoTreino, 1)
# print(rotuloPrevisto)
rotuloPrevisto = meuKnn(grupoTreino, treinoRots, grupoTreino, 1)

estaCorreto = rotuloPrevisto == testeRots
print(estaCorreto)

numCorreto = sum(estaCorreto)

totalNum = len(testeRots)

acuracia = numCorreto / totalNum

print(acuracia)
# Out:
# [[ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# [0.32]
